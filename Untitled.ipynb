# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
file_ACCESS = "Files/Copy of FoodEnvironmentAtlas - ACCESS.csv"

# %%
#output total file

file_ACCESS_df = pd.read_csv(file_ACCESS, encoding="ISO-8859-1")
pd.options.display.float_format = '{:,.2f}'.format
file_ACCESS_df
# Out:
#       ï»¿FIPS State      County  LACCESS_POP10  LACCESS_POP15  \
# 0        1001    AL     Autauga      18,428.44      17,496.69
# 1        1003    AL     Baldwin      35,210.81      30,561.26
# 2        1005    AL     Barbour       5,722.31       6,069.52
# 3        1007    AL        Bibb       1,044.87         969.38
# 4        1009    AL      Blount       1,548.18       3,724.43
# ...       ...   ...         ...            ...            ...
# 3138    56037    WY  Sweetwater      13,391.72      18,934.74
# 3139    56039    WY       Teton       6,212.42       6,212.39
# 3140    56041    WY       Uinta       4,270.15       4,686.02
# 3141    56043    WY    Washakie         931.41         931.41
# 3142    56045    WY      Weston       1,240.49       1,237.27
#
#       PCH_LACCESS_POP_10_15  PCT_LACCESS_POP10  PCT_LACCESS_POP15  \
# 0                     -5.06              33.77              32.06
# 1                    -13.20              19.32              16.77
# ...

# %%
#select only the columns I want

df1 = pd.DataFrame(file_ACCESS_df, columns= ['State','County','LACCESS_POP15','LACCESS_LOWI15'])#, index = 1["CO"])
new_row = pd.DataFrame({'State':'', 'County':'', 'LACCESS_POP15':'', 
                        'LACCESS_LOWI15':''}, index =[0])
df2 = pd.concat([new_row, df1[:]]).reset_index(drop = True) 
df2
# df2.head()
# Out:
#      State      County LACCESS_POP15 LACCESS_LOWI15
# 0
# 1       AL     Autauga     17,496.69       6,543.68
# 2       AL     Baldwin     30,561.26       9,886.83
# 3       AL     Barbour      6,069.52       2,948.79
# 4       AL        Bibb        969.38         596.16
# ...    ...         ...           ...            ...
# 3139    WY  Sweetwater     18,934.74       4,750.91
# 3140    WY       Teton      6,212.39       1,577.77
# 3141    WY       Uinta      4,686.02       2,054.18
# 3142    WY    Washakie        931.41         309.03
# 3143    WY      Weston      1,237.27         302.70
#
# [3144 rows x 4 columns]

# %%
#rename columns

renamed_df = df1.rename(columns={"LACCESS_POP15": "Low Access to Store '15","LACCESS_LOWI15":"Low Income Low Access to Store '15"})
renamed_df.head()
# Out:
#   State   County  Low Access to Store '15  Low Income Low Access to Store '15
# 0    AL  Autauga                17,496.69                            6,543.68
# 1    AL  Baldwin                30,561.26                            9,886.83
# 2    AL  Barbour                 6,069.52                            2,948.79
# 3    AL     Bibb                   969.38                              596.16
# 4    AL   Blount                 3,724.43                            1,650.96

# %%
#select colorado

colorado_df = renamed_df[renamed_df['State'].str.match('CO')]
colorado_df.head()
# Out:
#     State     County  Low Access to Store '15  \
# 244    CO      Adams                66,895.71
# 245    CO    Alamosa                   915.19
# 246    CO   Arapahoe                69,481.67
# 247    CO  Archuleta                 3,600.90
# 248    CO       Baca                   955.22
#
#      Low Income Low Access to Store '15
# 244                           24,845.52
# 245                              405.35
# 246                           13,732.22
# 247                            1,289.72
# 248                              318.13

# %%
colorado_df.boxplot(column=["Low Access to Store '15", "Low Income Low Access to Store '15"], vert=False)
colorado_mean_ =
# Out:
# <AxesSubplot:>

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-105-ad418b199861> in <module>
# ----> 1 colorado_df.boxplot(by="State", column=["CO", "AL"])
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     492 ):
#     493     plot_backend = _get_plot_backend(backend)
# --> 494     return plot_backend.boxplot_frame(
#     495         self,
#     496         column=column,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\boxplot.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     378     import matplotlib.pyplot as plt
#     379
# --> 380     ax = boxplot(
#     381         self,
#     382         column=column,
#
# ...
